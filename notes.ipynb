# %% [markdown]
# ## Start of PowerBi
# ### Step 1: Find out what type of dataset you have.
# - xlsx, csv etc.
# - For none techy, instead of checking properties and oh thats and excel file, just do right click anywhere on the folder, select view and then select details or you can do ctrl+shift+6
# ### What this does
# - provides what type it is and knowing how big your dataset is (mb,kb,gb etc)
# ### Step 2: Then get data and choose what type of data you have
# #### omg its s big!
# - which should i pick?
# - pick the blue ones, the tables that have blue on them shows excel tables and its purpose is to be able to use the dataset in a faster way and more professional. and when there is an excel highly suggested to pick
# #### what happens if i pick the non blue onese?
# - you pick the whole dataset not the table. which includes the spaces but if there are no other choices you may do so.
#
# ![bluetables.png](attachment:bluetables.png)
#
# ### Step 3: Load now? NO we will transform the data
# #### Why?
# - dont do that, EVER, as a data analyst, we have to prepare the data to get it ready to analyze. Its one of our tasks
# - First task is to ensure that the data is ready to model and ready to analyze, we can do that when doing transformation and data cleaning,
# #### What should i do?
# - Tranform Data
#
# ## others
# - Connection, cleaning, model, analysis

# %% [markdown]
# ## Data Transformation
# - Ensure the namesof the tables correct
# - We can check the datatypes by clicking on the logos beside their names.
# - Check data types, missing data, errors, etc.
# - In this tutorial he ensured correct names, data types correct in their columns.
#
# #### Confused about which data type to use
# - in data modeling, RDMS, the key is whole number, SKU text, IN SHORT anyother none computed like names, address, tel numbers, country SUggested to use text as data type.  if its like currency or dollars price, we can use fixed decimal

# %% [markdown]
# ## Data Modeling
# #### Why we have to establish a relationship?
# - We establish relationships to answer questions that are needed, just like which country has the biggest sales? etc etc. How will we find the country if it the ccountry is not established with the sales as a relationship??
# ### For example
# ![salesterritoryandsales.png](attachment:salesterritoryandsales.png)
# - This happens when the relationship isnt establushed
#
# ### Cardinality
# - Personal note, Oh i tackled this in my data warehousing and data mining it was fun
# - The legendary Many to one, one to many etc.
#
# #### Cross-filter Direction
# - Single and both
# - Both
#     - This is the most common, default direction. This means for filtering purposes, both tables are treated as if they're a single table.  This works well with a single table that has a number of lookup tables that surround it.  An example is a Sales actuals table with a lookup table for department.  This is often called a Star schema configuration (a central table with several Lookup tables.)  However, if you have two or more tables that also have lookup tables (with some in common) then you wouldn't want to use the Both setting.  To continue the previous example, in this case, you also have a budget sales table that records target budget for each department.  And, the department table is connected to both the sales and the budget table.  Avoid the Both setting for this kind of configuration.
# - Single
#     - This means that filtering choices in connected tables work on the table where values are being aggregated. If you import a Power Pivot in Excel 2013 or earlier data model, all relationships will have a single direction.
# See the Understanding advanced options section later in this article for more details about when to change cross filter direction.
#
# #### Ugly dataset
# - which company accepts a very ugly dataset
# - Fix the source so you do not have to always fix the 'top' of the output. You keep on editing a spelling everytime you do it why not fix it from the source?
# - Deal with the Process, validation, system proceess, database structuring etc.

# %% [markdown]
# ## DASHBOARD WIREFRAMING
# #### Layout Scanning Patterns
# - the predictable human eye
# ![dashboardwireframing.jpg](attachment:dashboardwireframing.jpg)
#
# - Place the most important visualization on the tp left

# %% [markdown]
# ## 4 KEYS to Storytelling with Data
# ![7b6af3c6-01fd-4116-a4ba-70f2fc9849ff.jpg](attachment:7b6af3c6-01fd-4116-a4ba-70f2fc9849ff.jpg)
# - Very important in using the correct charts
# ![types of data.jpg](<attachment:types of data.jpg>)
# ![visual.jpg](attachment:visual.jpg)

# %% [markdown]
# ## TOP CHARTS
# ![751b8f14-22db-44a6-a704-a4a572eccd93.jpg](attachment:751b8f14-22db-44a6-a704-a4a572eccd93.jpg)
#
# - Single Big Number
#     - Showing the most important metric
# - Ordered Bar Chart
#     - Compare categories
# - Line Chart
#     - Trends
# - Doughnut Chart
#     - Simple percentage or proportion and like big number in the middle
# - Matrix
#     - Complicaed data
#
# ### Data-ink Ratio
# - Above all else show the DATA
# - remove borders, colors, labels, boldings, lighten, lighten lines or remove, direct labeles.
# - Direct data is attractive

# %% [markdown]
# ## Little Rules or ultimate Rules Tips idk
# - Z formation or F formation
# - Choosing the right charts
# - Show data (keep the dashboard clean and simple)

# %% [markdown]
# ## Making the Dashboard
# - Use lighter, greyish colors in setting the canvas background color

# %% [markdown]
# ## Types of Measures
# - Implicit
#     - Drag and drop in the powerbi and using its Aggregation functions (add, sum, avg) for example.
# - Explicit
#     - Your own DAX expressions or own calculations.
